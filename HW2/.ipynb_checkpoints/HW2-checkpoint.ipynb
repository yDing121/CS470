# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./data.csv")
df.head()
# Out:
#                  tweet_created_at city of the user country of the user  \
# 0  Sun Apr 06 03:11:03 +0000 2014     Lincoln Park       United States
# 1  Sun Apr 06 04:06:01 +0000 2014       Montgomery       United States
# 2  Sun Apr 06 06:20:41 +0000 2014          Visalia       United States
# 3  Sun Apr 06 17:01:32 +0000 2014           Boston       United States
# 4  Sun Apr 06 17:07:17 +0000 2014           Albany       United States
#
#   state of the user      tweet_id  retweet_count  \
# 0          Michigan  4.526450e+17              0
# 1           alabama  4.526580e+17              0
# 2        California  4.526920e+17              0
# 3     Massachusetts  4.528540e+17              0
# 4          New York  4.528550e+17              0
#
#                                                 text  \
# 0  @xoBrittanyGlenn @Anggg_xoxo Railee got the fl...
# 1                  Need a flu shot cuz my watch sick
# 2  @andylassner: I'll grab something off a room s...
# 3  A cold in April.... even after getting a flu s...
# 4  last time all 302 followers I have are going t...
#
#                   text_keywords  user_favourites_count  user_friends_count  \
# 0            got;shot;still;flu                    937                 412
# 1            need;shot;sick;flu                   1896                 784
# 2       care;shot;something;flu                    178                  93
# 3    even;flu;shot;getting;cold                      8                1993
# 4  going;get;flu;last;time;shot                    702                 666
#
#    user_statuses_count  user_verified
# 0                 7518          False
# 1                43591          False
# 2                  224          False
# 3                  740          False
# 4                 2036          False

# %%
df.describe()
# Out:
#            tweet_id  retweet_count  user_favourites_count  user_friends_count  \
# count  2.620600e+04   26206.000000           26206.000000        26206.000000
# mean   5.012003e+17       0.004045            2819.068114          762.789857
# std    4.820605e+16       0.081385            9482.276402         4140.818058
# min    4.181700e+17       0.000000               0.000000            0.000000
# 25%    4.409188e+17       0.000000             149.000000          197.250000
# 50%    5.211580e+17       0.000000             732.000000          361.000000
# 75%    5.309675e+17       0.000000            2574.750000          691.750000
# max    5.940910e+17       7.000000          681620.000000       360790.000000
#
#        user_statuses_count
# count         26206.000000
# mean          15744.136534
# std           26890.928007
# min               0.000000
# 25%            2522.000000
# 50%            7067.500000
# 75%           17625.500000
# max          609809.000000

# %%
df.isna().sum()
# Out:
# tweet_created_at            0
# city of the user            0
# country of the user         0
# state of the user        2121
# tweet_id                    0
# retweet_count               0
# text                        0
# text_keywords               0
# user_favourites_count       0
# user_friends_count          0
# user_statuses_count         0
# user_verified               0
# dtype: int64

# %% [markdown]
# # Apriori Algorithm Implmentation
#
# We will use the framework given by Professor Kai Shu's notes as a guideline for implementing the Apriori algorithm. We build a general algorithm that takes in a pandas dataframe and operates on one column.

# %% [markdown]
# ![Screenshot from 2025-02-24 14-40-14.png](attachment:25f552a2-9593-4491-8ae8-e6c738255b46.png)

# %% [markdown]
# [Look here for more resources (in depth)](https://www-users.cse.umn.edu/~kumar001/dmbook/ch5_association_analysis.pdf)

# %%
def parse_keywords(keywords: str):
    return set(keywords.split(";"))

# %%
test_kws = df.iloc[0]["text_keywords"]
print(parse_keywords(test_kws))
# test_kws.split(";")
# Out:
# {'still', 'flu', 'shot', 'got'}

# %%
def generate_1_itemsets(df: pd.DataFrame, target_col: str, min_support: int) -> set:
    counts = {}

    for kw_line in df[target_col]:
        kws = kw_line.split(";")

        for kw in kws:
            if kw in counts:
                counts[kw] += 1
            else:
                counts[kw] = 1

    ans = set()

    for k, v in counts.items():
        if v >= min_support:
            ans.add((k, v))

    return ans

# %%
one_itemsets = generate_1_itemsets(df, "text_keywords", 500)
print(one_itemsets)
# Out:
# {('going', 770), ('free', 1013), ('mom', 552), ('sick', 1842), ('got', 7396), ('work', 968), ('get', 7647), ('every', 569), ('one', 915), ('vaccine', 519), ('getting', 3087), ('right', 541), ('need', 814), ('flu', 26186), ('feel', 1018), ('first', 633), ('shots', 2573), ('sore', 675), ('never', 917), ('still', 990), ('last', 664), ('arm', 2023), ('year', 1534), ('lol', 503), ('shot', 23167), ('even', 611), ('better', 593), ('like', 1940), ('really', 580), ('gotten', 695), ('hurts', 530), ('day', 759), ('know', 523), ('think', 649), ('amp', 959), ('time', 1404), ('today', 2729)}

# %%
def apriori(df: pd.DataFrame, target_col: str, min_support: int, candidates: set, ban: set):
    counts = {}

    one_itemsets = generate_1_itemset(df=df, target_col=target_col, min_support=min_support)

    if len(candidates) == 0:
        candidates = one_itemsets.copy()

# %% [markdown]
# # Testing

# %%
min_support = 500
