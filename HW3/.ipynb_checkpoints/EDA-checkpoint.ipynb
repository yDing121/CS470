# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#    person ID  age gender chest pain type  resting blood pressure  \
# 0          1   63      M          Type 3                     145
# 1          2   37      M          Type 2                     130
# 2          3   41      F          Type 1                     130
# 3          4   56      M          Type 1                     120
# 4          5   57      F          Type 0                     120
#
#    serum cholesterol in mg/dl fasting blood sugar > 120 mg/dl  \
# 0                         233                             Yes
# 1                         250                              No
# 2                         204                              No
# 3                         236                              No
# 4                         354                              No
#
#   resting electrocardiographic results  maximum heart rate achieved  \
# 0                 hypertrophy of heart                          150
# 1                myocardial infarction                          187
# 2                 hypertrophy of heart                          172
# 3                myocardial infarction                          178
# 4                myocardial infarction                          163
#
#   exercise induced angina  \
# 0                      No
# 1                      No
# 2                      No
# 3                      No
# 4                     Yes
#
#    oldpeak = ST depression induced by exercise relative to rest  \
# 0                                                2.3
# 1                                                3.5
# 2                                                1.4
# 3                                                0.8
# 4                                                0.6
#
#    the slope of the peak exercise ST segment  \
# 0                                          0
# 1                                          0
# 2                                          2
# 3                                          2
# 4                                          2
#
#    number of major vessels (0-3) colored by flourosopy  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#   Has heart disease? (Prediction Target)
# 0                                    Yes
# 1                                    Yes
# 2                                    Yes
# 3                                    Yes
# 4                                    Yes

# %%
# print(df.describe())
print(df.isna().sum())
# Out:
# person ID                                                       0
# age                                                             0
# gender                                                          0
# chest pain type                                                 0
# resting blood pressure                                          0
# serum cholesterol in mg/dl                                      0
# fasting blood sugar > 120 mg/dl                                 0
# resting electrocardiographic results                            0
# maximum heart rate achieved                                     0
# exercise induced angina                                         0
# oldpeak = ST depression induced by exercise relative to rest    0
# the slope of the peak exercise ST segment                       0
# number of major vessels (0-3) colored by flourosopy             0
# Has heart disease? (Prediction Target)                          0
# dtype: int64

# %% [markdown]
# # Preprocessing

# %%
label_mappings = {}
categorical_cols = [
    "gender",
    "chest pain type", 
    "fasting blood sugar > 120 mg/dl", 
    "resting electrocardiographic results",
    "exercise induced angina",
    "Has heart disease? (Prediction Target)"
]
encoded_df = df.copy()

for col in categorical_cols:
    encoder = LabelEncoder()
    encoded_df[col] = encoder.fit_transform(encoded_df[col])
    label_mappings[col] = dict(zip(encoder.classes_, encoder.transform(encoder.classes_)))

# %%
for k, v in label_mappings.items():
    print(k)

    for k2, v2 in v.items():
        print(f"{k2}:\t{v2}")
    print("---"*10)
# Out:
# gender
# F:	0
# M:	1
# ------------------------------
# chest pain type
# Type 0:	0
# Type 1:	1
# Type 2:	2
# Type 3:	3
# ------------------------------
# fasting blood sugar > 120 mg/dl
# No:	0
# Yes:	1
# ------------------------------
# resting electrocardiographic results
# hypertrophy of heart:	0
# ischemia:	1
# myocardial infarction:	2
# ------------------------------
# exercise induced angina
# No:	0
# Yes:	1
# ------------------------------
# Has heart disease? (Prediction Target)
# No:	0
# Yes:	1
# ------------------------------

# %% [markdown]
# # Development

# %%
def generate_splitpoints(df: pd.DataFrame, col: str):
    assert df is not None, "Dataframe does not exist"
    assert col in list(df.columns), "The column is not in the dataframe"
    assert pd.api.types.is_numeric_dtype(df[col]), "The column is not numeric"

    vals = df[col].unique()
    vals.sort()
    n = len(vals)

    ret = np.zeros(n - 1)
    
    for i in range(n - 1):
        ret[i] = 1/2 * (vals[i] + vals[i+1])

    return ret

# %%
def entropy(left: tuple, right: tuple, N: int):
    n_left = sum(left)
    n_right = sum(right)
    
    left_weight = n_left/N
    right_weight = sum(right)/N

    p_l_1 = left[0]/sum

# %%
def find_split(df: pd.DataFrame, split_col: str, label_col: str, metric: str = "entropy"):
    splitpoints = generate_splitpoints(df, split_col)
    
    data = df[[split_col, label_col]].to_numpy()
    data = data[data[:, 0].argsort()]

    for sp in splitpoints:
        print(sp)
        lt = data[data[:, 0] < sp]
        gt = data[data[:, 0] >= sp]

        split_lt = (len(lt[lt[:, 1] == 1]), len(lt[lt[:, 1] == 0]))
        split_gt = (len(gt[gt[:, 1] == 1]), len(gt[gt[:, 1] == 0]))

        print(f"Left size: {lt.shape[0]}\t | \t(1, 0): {split_lt}")
        print(f"Right size: {gt.shape[0]}\t | \t(1, 0): {split_gt}")
        print("---"*10)

# %%
find_split(encoded_df, "resting blood pressure", "Has heart disease? (Prediction Target)")
# Out:
# 97.0
# Left size: 2	 | 	(1, 0): (2, 0)
# Right size: 301	 | 	(1, 0): (163, 138)
# ------------------------------
# 100.5
# Left size: 6	 | 	(1, 0): (4, 2)
# Right size: 297	 | 	(1, 0): (161, 136)
# ------------------------------
# 101.5
# Left size: 7	 | 	(1, 0): (5, 2)
# Right size: 296	 | 	(1, 0): (160, 136)
# ------------------------------
# 103.0
# Left size: 9	 | 	(1, 0): (7, 2)
# Right size: 294	 | 	(1, 0): (158, 136)
# ------------------------------
# 104.5
# Left size: 10	 | 	(1, 0): (8, 2)
# Right size: 293	 | 	(1, 0): (157, 136)
# ------------------------------
# 105.5
# Left size: 13	 | 	(1, 0): (11, 2)
# Right size: 290	 | 	(1, 0): (154, 136)
# ------------------------------
# 107.0
# Left size: 14	 | 	(1, 0): (12, 2)
# Right size: 289	 | 	(1, 0): (153, 136)
# ------------------------------
# 109.0
# Left size: 20	 | 	(1, 0): (16, 4)
# Right size: 283	 | 	(1, 0): (149, 134)
# ------------------------------
# 111.0
# Left size: 39	 | 	(1, 0): (24, 15)
# Right size: 264	 | 	(1, 0): (141, 123)
# ------------------------------
# 113.0
# Left size: 48	 | 	(1, 0): (29, 19)
# Right size: 255	 | 	(1, 0): (136, 119)
# ------------------------------
# 114.5
# Left size: 49	 | 	(1, 0): (29, 20)
# Right size: 254	 | 	(1, 0): (136, 118)
# ------------------------------
# 116.0
# Left size: 52	 | 	(1, 0): (32, 20)
# Right size: 251	 | 	(1, 0): (133, 118)
# ------------------------------
# 117.5
# Left size: 53	 | 	(1, 0): (32, 21)
# Right size: 250	 | 	(1, 0): (133, 117)
# ------------------------------
# 119.0
# Left size: 60	 | 	(1, 0): (37, 23)
# Right size: 243	 | 	(1, 0): (128, 115)
# ------------------------------
# 121.0
# Left size: 97	 | 	(1, 0): (60, 37)
# Right size: 206	 | 	(1, 0): (105, 101)
# ------------------------------
# 122.5
# Left size: 101	 | 	(1, 0): (63, 38)
# Right size: 202	 | 	(1, 0): (102, 100)
# ------------------------------
# 123.5
# Left size: 102	 | 	(1, 0): (63, 39)
# Right size: 201	 | 	(1, 0): (102, 99)
# ------------------------------
# 124.5
# Left size: 108	 | 	(1, 0): (65, 43)
# Right size: 195	 | 	(1, 0): (100, 95)
# ------------------------------
# 125.5
# Left size: 119	 | 	(1, 0): (69, 50)
# Right size: 184	 | 	(1, 0): (96, 88)
# ------------------------------
# 127.0
# Left size: 122	 | 	(1, 0): (70, 52)
# Right size: 181	 | 	(1, 0): (95, 86)
# ------------------------------
# 128.5
# Left size: 134	 | 	(1, 0): (76, 58)
# Right size: 169	 | 	(1, 0): (89, 80)
# ------------------------------
# 129.5
# Left size: 135	 | 	(1, 0): (77, 58)
# Right size: 168	 | 	(1, 0): (88, 80)
# ------------------------------
# 131.0
# Left size: 171	 | 	(1, 0): (100, 71)
# Right size: 132	 | 	(1, 0): (65, 67)
# ------------------------------
# 133.0
# Left size: 179	 | 	(1, 0): (103, 76)
# Right size: 124	 | 	(1, 0): (62, 62)
# ------------------------------
# 134.5
# Left size: 184	 | 	(1, 0): (105, 79)
# Right size: 119	 | 	(1, 0): (60, 59)
# ------------------------------
# 135.5
# Left size: 190	 | 	(1, 0): (110, 80)
# Right size: 113	 | 	(1, 0): (55, 58)
# ------------------------------
# 137.0
# Left size: 193	 | 	(1, 0): (111, 82)
# Right size: 110	 | 	(1, 0): (54, 56)
# ------------------------------
# 139.0
# Left size: 206	 | 	(1, 0): (121, 85)
# Right size: 97	 | 	(1, 0): (44, 53)
# ------------------------------
# 141.0
# Left size: 238	 | 	(1, 0): (138, 100)
# Right size: 65	 | 	(1, 0): (27, 38)
# ------------------------------
# 143.0
# Left size: 241	 | 	(1, 0): (140, 101)
# Right size: 62	 | 	(1, 0): (25, 37)
# ------------------------------
# 144.5
# Left size: 243	 | 	(1, 0): (140, 103)
# Right size: 60	 | 	(1, 0): (25, 35)
# ------------------------------
# 145.5
# Left size: 248	 | 	(1, 0): (141, 107)
# Right size: 55	 | 	(1, 0): (24, 31)
# ------------------------------
# 147.0
# Left size: 250	 | 	(1, 0): (142, 108)
# Right size: 53	 | 	(1, 0): (23, 30)
# ------------------------------
# 149.0
# Left size: 252	 | 	(1, 0): (143, 109)
# Right size: 51	 | 	(1, 0): (22, 29)
# ------------------------------
# 151.0
# Left size: 269	 | 	(1, 0): (152, 117)
# Right size: 34	 | 	(1, 0): (13, 21)
# ------------------------------
# 153.0
# Left size: 274	 | 	(1, 0): (154, 120)
# Right size: 29	 | 	(1, 0): (11, 18)
# ------------------------------
# 154.5
# Left size: 275	 | 	(1, 0): (154, 121)
# Right size: 28	 | 	(1, 0): (11, 17)
# ------------------------------
# 155.5
# Left size: 276	 | 	(1, 0): (155, 121)
# Right size: 27	 | 	(1, 0): (10, 17)
# ------------------------------
# 158.0
# Left size: 277	 | 	(1, 0): (156, 121)
# Right size: 26	 | 	(1, 0): (9, 17)
# ------------------------------
# 162.0
# Left size: 288	 | 	(1, 0): (161, 127)
# Right size: 15	 | 	(1, 0): (4, 11)
# ------------------------------
# 164.5
# Left size: 289	 | 	(1, 0): (161, 128)
# Right size: 14	 | 	(1, 0): (4, 10)
# ------------------------------
# 167.5
# Left size: 290	 | 	(1, 0): (161, 129)
# Right size: 13	 | 	(1, 0): (4, 9)
# ------------------------------
# 171.0
# Left size: 294	 | 	(1, 0): (162, 132)
# Right size: 9	 | 	(1, 0): (3, 6)
# ------------------------------
# 173.0
# Left size: 295	 | 	(1, 0): (163, 132)
# Right size: 8	 | 	(1, 0): (2, 6)
# ------------------------------
# 176.0
# Left size: 296	 | 	(1, 0): (163, 133)
# Right size: 7	 | 	(1, 0): (2, 5)
# ------------------------------
# 179.0
# Left size: 298	 | 	(1, 0): (164, 134)
# Right size: 5	 | 	(1, 0): (1, 4)
# ------------------------------
# 186.0
# Left size: 301	 | 	(1, 0): (165, 136)
# Right size: 2	 | 	(1, 0): (0, 2)
# ------------------------------
# 196.0
# Left size: 302	 | 	(1, 0): (165, 137)
# Right size: 1	 | 	(1, 0): (0, 1)
# ------------------------------
