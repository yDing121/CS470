# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#    person ID  age gender chest pain type  resting blood pressure  \
# 0          1   63      M          Type 3                     145
# 1          2   37      M          Type 2                     130
# 2          3   41      F          Type 1                     130
# 3          4   56      M          Type 1                     120
# 4          5   57      F          Type 0                     120
#
#    serum cholesterol in mg/dl fasting blood sugar > 120 mg/dl  \
# 0                         233                             Yes
# 1                         250                              No
# 2                         204                              No
# 3                         236                              No
# 4                         354                              No
#
#   resting electrocardiographic results  maximum heart rate achieved  \
# 0                 hypertrophy of heart                          150
# 1                myocardial infarction                          187
# 2                 hypertrophy of heart                          172
# 3                myocardial infarction                          178
# 4                myocardial infarction                          163
#
#   exercise induced angina  \
# 0                      No
# 1                      No
# 2                      No
# 3                      No
# 4                     Yes
#
#    oldpeak = ST depression induced by exercise relative to rest  \
# 0                                                2.3
# 1                                                3.5
# 2                                                1.4
# 3                                                0.8
# 4                                                0.6
#
#    the slope of the peak exercise ST segment  \
# 0                                          0
# 1                                          0
# 2                                          2
# 3                                          2
# 4                                          2
#
#    number of major vessels (0-3) colored by flourosopy  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#   Has heart disease? (Prediction Target)
# 0                                    Yes
# 1                                    Yes
# 2                                    Yes
# 3                                    Yes
# 4                                    Yes

# %%
# print(df.describe())
print(df.isna().sum())
# Out:
# person ID                                                       0
# age                                                             0
# gender                                                          0
# chest pain type                                                 0
# resting blood pressure                                          0
# serum cholesterol in mg/dl                                      0
# fasting blood sugar > 120 mg/dl                                 0
# resting electrocardiographic results                            0
# maximum heart rate achieved                                     0
# exercise induced angina                                         0
# oldpeak = ST depression induced by exercise relative to rest    0
# the slope of the peak exercise ST segment                       0
# number of major vessels (0-3) colored by flourosopy             0
# Has heart disease? (Prediction Target)                          0
# dtype: int64

# %%
def generate_splitpoints(df: pd.DataFrame, col: str):
    assert df is not None, "Dataframe does not exist"
    assert col in list(df.columns), "The column is not in the dataframe"
    assert pd.api.types.is_numeric_dtype(df[col]), "The column is not numeric"

    vals = df[col].unique()
    vals.sort()
    n = len(vals)

    ret = np.zeros(n - 1)
    
    for i in range(n - 1):
        ret[i] = 1/2 * (vals[i] + vals[i+1])

    return ret

# %%
def find_split(df: pd.DataFrame, split_col: str, label_col: str, metric: str = "entropy"):
    splitpoints = generate_splitpoints(df, split_col)
    
    data = df[[split_col, label_col]].to_numpy()
    data = data[data[:, 0].argsort()]
    return data

# %%
generate_splitpoints(df, "resting blood pressure")
# Out:
# array([ 97. , 100.5, 101.5, 103. , 104.5, 105.5, 107. , 109. , 111. ,
#        113. , 114.5, 116. , 117.5, 119. , 121. , 122.5, 123.5, 124.5,
#        125.5, 127. , 128.5, 129.5, 131. , 133. , 134.5, 135.5, 137. ,
#        139. , 141. , 143. , 144.5, 145.5, 147. , 149. , 151. , 153. ,
#        154.5, 155.5, 158. , 162. , 164.5, 167.5, 171. , 173. , 176. ,
#        179. , 186. , 196. ])

# %%
find_split(df, "resting blood pressure", "Has heart disease? (Prediction Target)")
# Out:
# array([[94, 'Yes'],
#        [94, 'Yes'],
#        [100, 'No'],
#        [100, 'Yes'],
#        [100, 'No'],
#        [100, 'Yes'],
#        [101, 'Yes'],
#        [102, 'Yes'],
#        [102, 'Yes'],
#        [104, 'Yes'],
#        [105, 'Yes'],
#        [105, 'Yes'],
#        [105, 'Yes'],
#        [106, 'Yes'],
#        [108, 'Yes'],
#        [108, 'No'],
#        [108, 'Yes'],
#        [108, 'No'],
#        [108, 'Yes'],
#        [108, 'Yes'],
#        [110, 'No'],
#        [110, 'No'],
#        [110, 'No'],
#        [110, 'No'],
#        [110, 'No'],
#        [110, 'No'],
#        [110, 'Yes'],
#        [110, 'Yes'],
#        [110, 'Yes'],
#        [110, 'No'],
#        [110, 'No'],
#        [110, 'Yes'],
#        [110, 'Yes'],
#        [110, 'Yes'],
#        [110, 'No'],
#        [110, 'No'],
#        [110, 'No'],
#        [110, 'Yes'],
#        [110, 'Yes'],
#        [112, 'Yes'],
#        [112, 'No'],
#        [112, 'No'],
#        [112, 'Yes'],
#        [112, 'Yes'],
#        [112, 'Yes'],
#        [112, 'Yes'],
#        [112, 'No'],
#        [112, 'No'],
#        [114, 'No'],
#        [115, 'Yes'],
#        [115, 'Yes'],
#        [115, 'Yes'],
#        [117, 'No'],
#        [118, 'Yes'],
#        [118, 'Yes'],
#        [118, 'No'],
#        [118, 'No'],
#        [118, 'Yes'],
#        [118, 'Yes'],
#        [118, 'Yes'],
#        [120, 'Yes'],
#        [120, 'Yes'],
#        [120, 'Yes'],
#        [120, 'Yes'],
#        [120, 'No'],
#        [120, 'No'],
#        [120, 'Yes'],
#        [120, 'Yes'],
#        [120, 'No'],
#        [120, 'Yes'],
#        [120, 'Yes'],
#        [120, 'No'],
#        [120, 'Yes'],
#        [120, 'Yes'],
#        [120, 'No'],
#        [120, 'Yes'],
#        [120, 'No'],
#        [120, 'Yes'],
#        [120, 'No'],
#        [120, 'No'],
#        [120, 'Yes'],
#        [120, 'No'],
#        [120, 'Yes'],
#        [120, 'Yes'],
#        [120, 'No'],
#        [120, 'Yes'],
#        [120, 'Yes'],
#        [120, 'Yes'],
#        [120, 'Yes'],
#        [120, 'No'],
#        [120, 'Yes'],
#        [120, 'No'],
#        [120, 'No'],
#        [120, 'Yes'],
#        [120, 'No'],
#        [120, 'Yes'],
#        [120, 'Yes'],
#        [122, 'Yes'],
#        [122, 'Yes'],
#        [122, 'No'],
#        [122, 'Yes'],
#        [123, 'No'],
#        [124, 'Yes'],
#        [124, 'No'],
#        [124, 'No'],
#        [124, 'Yes'],
#        [124, 'No'],
#        [124, 'No'],
#        [125, 'No'],
#        [125, 'No'],
#        [125, 'No'],
#        [125, 'No'],
#        [125, 'No'],
#        [125, 'Yes'],
#        [125, 'Yes'],
#        [125, 'No'],
#        [125, 'Yes'],
#        [125, 'No'],
#        [125, 'Yes'],
#        [126, 'No'],
#        [126, 'Yes'],
#        [126, 'No'],
#        [128, 'Yes'],
#        [128, 'No'],
#        [128, 'No'],
#        [128, 'No'],
#        [128, 'No'],
#        [128, 'Yes'],
#        [128, 'No'],
#        [128, 'No'],
#        [128, 'Yes'],
#        [128, 'Yes'],
#        [128, 'Yes'],
#        [128, 'Yes'],
#        [129, 'Yes'],
#        [130, 'Yes'],
#        [130, 'No'],
#        [130, 'Yes'],
#        [130, 'No'],
#        [130, 'No'],
#        [130, 'No'],
#        [130, 'No'],
#        [130, 'No'],
#        [130, 'No'],
#        [130, 'No'],
#        [130, 'No'],
#        [130, 'No'],
#        [130, 'No'],
#        [130, 'Yes'],
#        [130, 'No'],
#        [130, 'No'],
#        [130, 'Yes'],
#        [130, 'Yes'],
#        [130, 'Yes'],
#        [130, 'Yes'],
#        [130, 'Yes'],
#        [130, 'Yes'],
#        [130, 'Yes'],
#        [130, 'Yes'],
#        [130, 'Yes'],
#        [130, 'Yes'],
#        [130, 'Yes'],
#        [130, 'Yes'],
#        [130, 'Yes'],
#        [130, 'Yes'],
#        [130, 'Yes'],
#        [130, 'Yes'],
#        [130, 'Yes'],
#        [130, 'Yes'],
#        [130, 'Yes'],
#        [130, 'Yes'],
#        [132, 'Yes'],
#        [132, 'Yes'],
#        [132, 'No'],
#        [132, 'Yes'],
#        [132, 'No'],
#        [132, 'No'],
#        [132, 'No'],
#        [132, 'No'],
#        [134, 'No'],
#        [134, 'Yes'],
#        [134, 'No'],
#        [134, 'Yes'],
#        [134, 'No'],
#        [135, 'No'],
#        [135, 'Yes'],
#        [135, 'Yes'],
#        [135, 'Yes'],
#        [135, 'Yes'],
#        [135, 'Yes'],
#        [136, 'No'],
#        [136, 'No'],
#        [136, 'Yes'],
#        [138, 'No'],
#        [138, 'No'],
#        [138, 'No'],
#        [138, 'Yes'],
#        [138, 'Yes'],
#        [138, 'Yes'],
#        [138, 'Yes'],
#        [138, 'Yes'],
#        [138, 'Yes'],
#        [138, 'Yes'],
#        [138, 'Yes'],
#        [138, 'Yes'],
#        [138, 'Yes'],
#        [140, 'No'],
#        [140, 'Yes'],
#        [140, 'Yes'],
#        [140, 'Yes'],
#        [140, 'No'],
#        [140, 'No'],
#        [140, 'Yes'],
#        [140, 'No'],
#        [140, 'No'],
#        [140, 'Yes'],
#        [140, 'No'],
#        [140, 'Yes'],
#        [140, 'No'],
#        [140, 'Yes'],
#        [140, 'Yes'],
#        [140, 'Yes'],
#        [140, 'Yes'],
#        [140, 'No'],
#        [140, 'No'],
#        [140, 'Yes'],
#        [140, 'Yes'],
#        [140, 'Yes'],
#        [140, 'Yes'],
#        [140, 'No'],
#        [140, 'No'],
#        [140, 'No'],
#        [140, 'Yes'],
#        [140, 'No'],
#        [140, 'Yes'],
#        [140, 'No'],
#        [140, 'Yes'],
#        [140, 'No'],
#        [142, 'Yes'],
#        [142, 'No'],
#        [142, 'Yes'],
#        [144, 'No'],
#        [144, 'No'],
#        [145, 'Yes'],
#        [145, 'No'],
#        [145, 'No'],
#        [145, 'No'],
#        [145, 'No'],
#        [146, 'No'],
#        [146, 'Yes'],
#        [148, 'Yes'],
#        [148, 'No'],
#        [150, 'Yes'],
#        [150, 'Yes'],
#        [150, 'No'],
#        [150, 'No'],
#        [150, 'Yes'],
#        [150, 'Yes'],
#        [150, 'No'],
#        [150, 'Yes'],
#        [150, 'No'],
#        [150, 'Yes'],
#        [150, 'Yes'],
#        [150, 'No'],
#        [150, 'Yes'],
#        [150, 'Yes'],
#        [150, 'No'],
#        [150, 'No'],
#        [150, 'No'],
#        [152, 'Yes'],
#        [152, 'Yes'],
#        [152, 'No'],
#        [152, 'No'],
#        [152, 'No'],
#        [154, 'No'],
#        [155, 'Yes'],
#        [156, 'Yes'],
#        [160, 'Yes'],
#        [160, 'No'],
#        [160, 'No'],
#        [160, 'Yes'],
#        [160, 'No'],
#        [160, 'Yes'],
#        [160, 'Yes'],
#        [160, 'No'],
#        [160, 'No'],
#        [160, 'Yes'],
#        [160, 'No'],
#        [164, 'No'],
#        [165, 'No'],
#        [170, 'Yes'],
#        [170, 'No'],
#        [170, 'No'],
#        [170, 'No'],
#        [172, 'Yes'],
#        [174, 'No'],
#        [178, 'No'],
#        [178, 'Yes'],
#        [180, 'No'],
#        [180, 'No'],
#        [180, 'Yes'],
#        [192, 'No'],
#        [200, 'No']], dtype=object)
